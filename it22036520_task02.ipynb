# %%
import numpy as np
import pandas as pd
print("IT22036520")
print("TASK 01 ")
print("Jathudshan Rajenthiran")
# Out:
# IT22036520
# TASK 01
# Jathudshan Rajenthiran

# %%
 df = pd.read_csv('Au_nanoparticle_dataset.csv')

# %%
Except_columns = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

filtered_df = df.drop(columns=Except_columns, axis=1)


print("Successfully created filtered DataFrame:")
# Out:
# Successfully created filtered DataFrame:

# %%
filtered_df.head(1)
# Out:
#    ID    T       tau  time        Volume    R_min    R_max  R_diff  R_std  \
# 0   1  273  0.000025     1  2.710000e-26  15.5898  19.4516  3.8618  0.623
#
#    R_skew  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0 -0.0435  ...         0         0         0         0         0         0
#
#    q6q6_S20  q6q6_S20+    Total_E  Formation_E
# 0         0          0 -5908.6345     343.4555
#
# [1 rows x 181 columns]

# %%
print("\nMean values:")
print(Except_columns.mean())

print("\nStandard Deviation values:")
print(Except_columns.std())

print("\nQuartile values (25th, 50th/Median, 75th percentile):")
print(Except_columns.quantile([0.25, 0.5, 0.75]))
# Out:
# Mean values:
# N_total      3476.786500
# N_bulk       2521.550250
# N_surface     955.236250
# R_avg          20.654363
# dtype: float64
#
# Standard Deviation values:
# N_total      3679.286769
# N_bulk       2976.232459
# N_surface     721.870220
# R_avg           7.610716
# dtype: float64
#
# Quartile values (25th, 50th/Median, 75th percentile):
#       N_total   N_bulk  N_surface      R_avg
# 0.25   1061.0   618.75     437.00  15.160725
# 0.50   1867.0  1199.00     666.00  18.629250
# 0.75   4503.0  3183.00    1301.75  25.525125

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1, ncols=len(Except_columns.columns), figsize=(20, 5))

for i, col in enumerate(Except_columns.columns):
    axes[i].hist(Except_columns[col], bins='auto')
    axes[i].set_title(f'Histogram of {col}')
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Frequency")

plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(Except_columns)

plt.suptitle('Pairplot of Filtered Au Nanoparticle Dataset Features', y=1.02, fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.98]) 


plt.show()

# %%
g = sns.PairGrid(Except_columns)


g.map_diag(sns.histplot, kde=True, color='purple')


g.map_lower(sns.kdeplot, cmap='Blues_d')


g.map_upper(sns.histplot, cmap='Greens')


g.fig.suptitle('Customized PairGrid: Histograms+KDE (Diag), Bivariate KDE (Lower), Bivariate Hist (Upper)',
               y=1.02, fontsize=16)

plt.show()

print("\n--- Customized PairGrid displayed. ---")
print("The diagonal plots now include both histograms and KDE curves.")
print("The lower triangle plots now show bivariate KDE contours.")
print("The upper triangle plots remain bivariate histograms.")
# Out:
# --- Customized PairGrid displayed. ---
# The diagonal plots now include both histograms and KDE curves.
# The lower triangle plots now show bivariate KDE contours.
# The upper triangle plots remain bivariate histograms.
